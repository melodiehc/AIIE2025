# %% [markdown]
# #**AIIE 2025 Python Review**
#
#   **Dr. Christelle Scharff | Dr. Kaleema**

# %% [markdown]
# In this notebook we will review the Data Types supported in Python

# %% [markdown]
# # Numeric Data Types in Python!
#
# In this Notebook, we will discuss on Python Numeric Data types and how to use them.
#
# Learning Objectives
#
#     1.) Types of Numeric Data in Python
#     2.) Basic Arithmetic operations
#     3.) Assignment of Objects or Object References in Python

# %% [markdown]
# ## Types of nummeric data
#
# Python has various "types" of data. In this notebook we will focus on following numeric data:
#
#  integers and floating point numbers.
#
# 1.   Integers a.k.a 'int'
# 2.   Floating Point a.k.a. 'float'
#
#
#
# Integers are whole numbers, positive or negative. For example: 2 and -2 are examples of integers.
#
# The size of Python’s integers is limited only by machine memory, not by a fixed number of bytes.
#
# Floating point numbers in Python are notable because they have a decimal point in them, or use an exponential (e) to define the number. For example 2.0 and -2.1 are examples of floating point numbers. 4E2 (4 times 10 to the power of 2) is also an example of a floating point number in Python.

# %% [markdown]
# <table>
# <tr>
#     <th>Data Type</th>
#     <th> Examples</th>
# </tr>
#
# <tr>
#     <td>Integers - int </td>
#     <td> 1, 10, -100, 1000 </td>
# </tr>
#
# <tr>
#     <td>Floating-point numbers - float </td>
#     <td> 1.2, -2.5, 2e2, 3E2  </td>
# </tr>
#  </table>

# %% [markdown]
# ### Basic Arithmetic

# %%
# Addition
2+1
# Out:
# 3

# %%
# Subtraction
2-1
# Out:
# 1

# %%
# Multiplication
2*2
# Out:
# 4

# %%
# Division
3/2
# Out:
# 1.5

# %%
# Floor Division - ex: how many times 4 goes into 7
7//4
# Out:
# 1

# %% [markdown]
#  "*floor*" division(The // operator (two forward slashes)) truncates the decimal without rounding, and returns an integer result.

# %% [markdown]
# **If you wan the remainder after division you need to use modulo which is represented as '%'**

# %%
# Modulo
5%3
# Out:
# 2

# %% [markdown]
# 3 divides 5 once, with a remainder of 2. The % operator returns the remainder after division.

# %%
# Powers
2**3
# Out:
# 8

# %%
# Can also do roots this way
4**0.5
# Out:
# 2.0

# %%
# Order of Operations followed in Python
2 + 10 * 10 + 3
# Out:
# 105

# %%
# Can use parentheses to specify orders
(2+10) * (10+3)
# Out:
# 156

# %% [markdown]
# ## Variable Assignments / Object Reference
#
# We can assign names and create variables as below.
# A '=' single equals sign to assign labels to variables.

# %%
# Below command creates an object called "a" and assign it the number 7
a = 7

# %% [markdown]
# Now if I call ' **a** ' in my Python script,it will treat it as the number 7![Picture1.png](data:image/png;base64,...).

# %%
b = a

# %%
# Adding the objects
a+a
# Out:
# 14

# %%
#Check a

a
# Out:
# 7

# %% [markdown]
# What happens on reassignment? Will Python let us write it over?

# %%
# Reassignment
a = "Liberty"

# %%
# Check
a
# Out:
# 'Liberty'

# %% [markdown]
# Yes! Python allows you to write over assigned variable names. We can also use the variables themselves when doing the reassignment. Here is an example of what I mean:

# %%
# Check
a
# Out:
# 'Liberty'

# %% [markdown]
# Using variable names in coding very useful way to keep track of different objects in Python. For example:

# %%
# Example1 : Calculate tax based on income.
# Creating different variables
income = 100

tax_rate = 0.1

my_taxes = income*tax_rate

# %%
# Show my taxes!
my_taxes
# Out:
# 10.0

# %% [markdown]
# ## Strings

# %% [markdown]
# ## Creating a String
# To create a string in Python you need to use either single quotes or double quotes. For example:

# %%
# Single word
'hello'

# %%
# Entire phrase
'This is also a string'

# %%
# We can also use double quote
"String built with double quotes"

# %%
# Be careful with quotes!
' I'm using single quotes, but this will create an error'

# %% [markdown]
# The reason for the error above is because the single quote in <code>I'm</code> stopped the string. You can use combinations of double and single quotes to get the complete statement.

# %%
"Now I'm ready to use the single quotes inside a string!"

# %% [markdown]
# ## String Indexing

# %%
# Assign s as a string
s = 'Hello World'

# %%
#Check
s

# %%
# Print the object
print(s)

# %%
# Show first element (in this case a letter)
s[0]

# %%
s[1]
# Out:
# 'e'

# %%
s[2]

# %% [markdown]
# We can use a <code>:</code> to perform *slicing* which grabs everything up to a designated point. For example:

# %%
# Grab everything PAST the first term all the way to the length of s which is len(s)
s[1:]
# Out:
# 'ello World'

# %%
# Note that there is no change to the original s
s

# %%
# Grab everything UP TO the 3rd index
s[:3]

# %%
# Last letter (one index behind 0 so it loops back around)
s[-1]

# %%
# Grab everything, but go in step sizes of 2
s[::2]

# %% [markdown]
# ## String Properties

# %%
s
# Out:
# 'Hello World concatenate me!'

# %%
# Let's try to change the first letter to 'x'
s[0] = 'x'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-976942677f11> in <cell line: 0>()
#       1 # Let's try to change the first letter to 'x'
# ----> 2 s[0] = 'x'
#
# TypeError: 'str' object does not support item assignment

# %%
# Concatenate strings!
s + ' concatenate me!'
# Out:
# 'Hello World concatenate me! concatenate me! concatenate me! concatenate me!'

# %%
# We can reassign s completely though!
s = s + ' concatenate me!'

# %%
print(s)
# Out:
# Hello World concatenate me! concatenate me! concatenate me! concatenate me! concatenate me!

# %%
#We can use the multiplication symbol to create repetition!
letter = 'z'
letter*10
# Out:
# 'zzzzzzzzzz'

# %% [markdown]
# ## Basic Built-in String methods
#
# We call methods with a period and then the method name. Methods are in the form:
#
# object.method(parameters)
#
# Let's explore some examples of built-in methods in strings:

# %%
# Upper Case a string
s.upper()
# Out:
# 'HELLO WORLD CONCATENATE ME! CONCATENATE ME! CONCATENATE ME! CONCATENATE ME! CONCATENATE ME!'

# %%
# Lower case
s.lower()

# %%
# Split a string by blank space (this is the default)
s.split()
# Out:
# ['Hello',
#  'World',
#  'concatenate',
#  'me!',
#  'concatenate',
#  'me!',
#  'concatenate',
#  'me!',
#  'concatenate',
#  'me!',
#  'concatenate',
#  'me!']

# %%
# Split by a specific element (doesn't include the element that was split on)
s.split('W')

# %% [markdown]
# ## Printing a String
#
# Using a notebook with just a string in a cell will automatically output strings, but the correct way to display strings in your output is by using a print function.

# %%
# We can simply declare a string
'Hello World'

# %%
# Note that we can't output multiple strings this way
'Hello World 1'
'Hello World 2'

# %% [markdown]
# We can use a print statement to print a string.

# %%
print('Hello World 1')
print('Hello World 2')
print('Use \n to print a new line')
print('\n')
print('See what I mean?')

# %%
course ="Python"

# %%
course.

# %%
string1 ="Python"
string2 = "Programming"
print("String1 {} and String2 {}".format(string1, string2))
# Out:
# String1 Python and String2 Programming

# %%
print("String1 {} and String2 {}".format("String1 goes here!!", "String2 goes here!!"))
# Out:
# String1 String1 goes here!! and String2 String2 goes here!!

# %%
#if you have to print floating numbers you can format it to limited decimal places
randomnumber = 500/655

# %%
randomnumber
# Out:
# 0.7633587786259542

# %%
print("The random number is {r:1.4f}".format(r = randomnumber))
# Out:
# The random number is 0.7634

# %%
print("The random number is {r:20.4f}".format(r = randomnumber))
# Out:
# The random number is               0.7634

# %%
name ="Sam"
age = 12

print(f'Hello {name}, your age is {age}')
# Out:
# Hello Sam, your age is 12

# %% [markdown]
# ## List

# %%
# Creating a list named my_list of all integer data type
my_list = [1,2,3]

# %%
 # Creating a list named my_list_all, which hold different object types.
 my_list_all = ['A string',23,100.232,'o']

# %%
my_list_all
# Out:
# ['A string', 23, 100.232, 'o']

# %%
# len() function will tell you how many items(Not indices) are in the sequence of the list.
len(my_list)
# Out:
# 3

# %% [markdown]
# ### Indexing and Slicing

# %%
# Get the element at index 0
my_list_all[0]
# Out:
# 'A string'

# %%
my_list_all[1:]
# Out:
# [23, 100.232, 'o']

# %%
my_list_all[:3]
# Out:
# ['A string', 23, 100.232]

# %%
# We can use + to concatenate lists, just like we did for strings.

my_list_all = my_list_all + ['new item']

# %%
my_list_all
# Out:
# ['A string', 23, 100.232, 'o', 'new item', 'new item']

# %% [markdown]
# ### Nested List

# %%
#Multiple lists
lst_1=[1,2,3]
lst_2=[4,5,6]
lst_3=[7,8,9]

# %%
# Make a list of lists
nested_list = [lst_1,lst_2,lst_3]

# %%
nested_list
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %% [markdown]
# ### Basic List Methods
#
#
# Let's go ahead and explore some more special methods for lists:

# %%
# Create a numeric list
list1 = [1,2,3]

# %%
# Append a string item to the list.
list1.append('append me!')

# %%
# Show
list1
# Out:
# [1, 2, 3, 'append me!', 'append me!']

# %%
# Pop off the 0 indexed item
list1.pop(0)
# Out:
# 1

# %%
# Show
list1
# Out:
# [2, 3, 'append me!', 'append me!']

# %%
# Assign the popped element, remember default popped index is -1
popped_item = list1.pop()

# %%
popped_item
# Out:
# 'append me!'

# %%
# Show remaining list
list1
# Out:
# [2, 3, 'append me!']

# %%
# sort method and the reverse methods
new_list = ['a','e','x','b','c']
new_list.reverse()

# %%
new_list
# Out:
# ['c', 'b', 'x', 'e', 'a']

# %%
new_list.sort()

# %%
new_list
# Out:
# ['a', 'b', 'c', 'e', 'x']

# %%
#Exercise

# %%
#create a list of at least 3 fruits
fruit_list = [ "apple", "banana", "mango","cherry"]

# %%
#Use append to add a fruit to the list
fruit_list.append("orange")

# %%
#call the list
fruit_list
# Out:
# ['apple', 'banana', 'mango', 'cherry', 'orange']

# %%
#sort the list
fruit_list.sort()
fruit_list
# Out:
# ['apple', 'banana', 'cherry', 'mango', 'orange']

# %%
#get the element at position 2 in the list
fruit_list[1]
# Out:
# 'banana'

# %% [markdown]
# ## Dictionaries
#
# A Python dictionary consists of a key-value pair, and value can be almost any Python object.

# %% [markdown]
# ### Constructing a Dictionary
# Let's see how we can construct dictionaries in Python.

# %%
# Creating a dictionary to signify a key and a value
my_dict1 = {'key1':'value1','key2':'value2'}

# %%
# Call values by their key
my_dict1['key2']
# Out:
# 'value2'

# %%
#Dictionary with different Python objects
my_dict2 = {'key1':123,'key2':[12,23,33],'key3':['item0','item1','item2']}

# %%
# Create an empty dictionary
d = {}

# %%
# Create a new key through assignment
d['animal'] = 'Dog'

# %%
d
# Out:
# {'animal': 'Dog'}

# %% [markdown]
# ### Accessing the items from a Dictionary

# %%
# Call items from the dictionary
my_dict2 = {'key1':123,'key2':[12,23,33],'key3':['item0','item1','item2']}
my_dict2['key3']
# Out:
# ['item0', 'item1', 'item2']

# %%
#To get the first item of value which is a list object
my_dict2['key3'][0]
# Out:
# 'item0'

# %% [markdown]
# ### Call methods on Dictionary items

# %%
# Call methods on values
my_dict2['key3'][0].upper()
# Out:
# 'ITEM0'

# %% [markdown]
# ### Perform Arithmetic operations on Items of dictionary

# %%
my_dict2['key1'] = my_dict2['key1']- 10

# %%
my_dict2
# Out:
# {'key1': 113, 'key2': [12, 23, 33], 'key3': ['item0', 'item1', 'item2']}

# %%
my_dict2['key1'] = my_dict2['key1']*10

# %%
my_dict2
# Out:
# {'key1': 1130, 'key2': [12, 23, 33], 'key3': ['item0', 'item1', 'item2']}

# %% [markdown]
# ### Nesting with Dictionaries
#
# Lets create a dictionary nested inside a dictionary.

# %%
# Dictionary nested inside a dictionary nested inside a dictionary
d = {'key1':{'nestkey':{'subnestkey':'value'}}}

# %%
d['key1']
# Out:
# {'nestkey': {'subnestkey': 'value'}}

# %%
d['key1']['nestkey']
# Out:
# {'subnestkey': 'value'}

# %%
d['key1']['nestkey']['subnestkey']
# Out:
# 'value'

# %% [markdown]
# ### Methods of Dictinary

# %%
# Method to return a list of all keys
d ={'k1':1,'k2':2, 'k3':3, 'k4':4}
d.keys()
# Out:
# dict_keys(['k1', 'k2', 'k3', 'k4'])

# %%
# Method to grab all values
d.values()
# Out:
# dict_values([1, 2, 3, 4])

# %%
# Method to all items
d.items()
# Out:
# dict_items([('k1', 1), ('k2', 2), ('k3', 3), ('k4', 4)])

# %% [markdown]
# ## Tuples

# %% [markdown]
# ### Creating the tuples

# %%
# Create a tuple
t1 = (1,2,3)

# %%
#Check the type of object
type(t1)
# Out:
# tuple

# %%
# Show the tuple
t1
# Out:
# (1, 2, 3)

# %%
#Slice the items of the tuples with indexing.
t1[0]
# Out:
# 1

# %%
t1[-1]
# Out:
# 3

# %% [markdown]
# ### Methods

# %%
# Use .index to enter a value and return the index
t2 =('one', 'two','three', 'one', 'three', 'one')
t2.index('two')
# Out:
# 1

# %%
t2.count('one') #couts the number of times the string appears in the list
# Out:
# 3

# %% [markdown]
# ### Immutability

# %%
t2 =('one', 'two','three', 'one', 'three', 'one')
t2[0] ='ten'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-5b7125004110> in <module>()
#       1 t2 =('one', 'two','three', 'one', 'three', 'one')
# ----> 2 t2[0] ='ten'
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ## Sets

# %%
#Creating a set 'x'
x = set()

# %%
x
# Out:
# set()

# %%
#Adding elements to a set
x.add(1)

# %%
x
# Out:
# {1}

# %%
#Adding elements to a set
x.add(2)

# %%
#Adding elements to a set
x.add(3)

# %%
x
# Out:
# {1, 2, 3}

# %%
# Try to add the same element
x.add(1)

# %%
x
# Out:
# {1, 2, 3}

# %%
# Create a list with repeats
list1 = [1,1,2,2,3,4,5,6,1,1]

# %%
# Cast as set to get unique values
set(list1)
# Out:
# {1, 2, 3, 4, 5, 6}

# %% [markdown]
# ## Booleans

# %%
# Set object to be a boolean
a = True

# %%
#Show
a
# Out:
# True

# %%
# Output is boolean
1 > 2
# Out:
# False

# %%
# None placeholder
b = None

# %%
print(b)
# Out:
# None
