# %% [markdown]
# ##Knowlwdge Check - 1
# ## Melodie Cornelly

# %% [markdown]
# ### Printing output

# %% [markdown]
# 1 - Using print(), print your name and city following the format:
#
#         Name : Angela
#         City : New York

# %%
print("Name: Angela")
print("City: New York")

# %% [markdown]
# 2 - Print the message below
#
#      Emergency Alert
#      NEWS : FLASH FLOOD WARNING this area till 7:00 PM

# %%
print("Emergency Alert")
print("NEWS: FLASH FLOOD WARNING this area till 7:00PM")
# Out:
# Emergency Alert
# NEWS: FLASH FLOOD WARNING this area till 7:00PM

# %% [markdown]
# ### Arithmetic Operators and Variables

# %% [markdown]
# 3 - Take a number and divide it by 2, then take the output and divide it by 2, and again divide by 2. Use variables.
#
#
#     Example
#     input : 2000
#     output is: 1000 500 250

# %%
number = int(input("Enter a number "))
result = number // 2
result2 = result // 2
result3 = result2 // 2
print(result,result2,result3)

# %% [markdown]
# 4 - Given three number x, y, and z,
#
#
#        Output: x to the power of z,
#                x to the power of y,
#                x minus y,
#                remainder value when x is divided by z

# %%
x = 2
y = 4
z = 6

result1 = x**z
result2 = x**y
result3 = x - y
result4 = x%z
print(result1)
print(result2)
print(result3)
print(result4)
# Out:
# 64
# 16
# -2
# 2

# %% [markdown]
# 5 - Add
#
#         4 quarters (0.25),  3 dimes (0.10), 2 nickels (0.5) and 1 cent
#         Output:  the total amount as dollars and cents.

# %%
x = 1.00 + 0.30 + 0.10 + 0.01
print("The total is: " "${:1.2f}".format(x))
# Out:
# The total is: $1.41

# %%
# Out:
# The random number is 0.7634

# %% [markdown]
# ### Strings

# %% [markdown]
# 6 - Given the string **Python**, with the help of slicing, get **o**.

# %%
x = "Python"
x[4:5]
# Out:
# 'o'

# %% [markdown]
# 7 - Given the string **Python**, with the help of slicing get,  **tho**.

# %%
x = "Python"
x[2:5]
# Out:
# 'tho'

# %% [markdown]
# 8 - Given the string **Python Class**, with the help of slicing, get **Class**.

# %%
x = "Python Class"
x[6:12]
# Out:
# ' Class'

# %% [markdown]
# 9 - Find the length of the String  **Welcome to Pace University**

# %%
x = "Welcome to Pace University"
len(x)
# Out:
# 26

# %% [markdown]
# 10 - Split the String  **Welcome to Pace University**  into words

# %%
string1 ="Welcome to Pace University"
words_list =string1.split()
print(words_list)
# Out:
# ['Welcome', 'to', 'Pace', 'University']

# %% [markdown]
# 11 - Replace the letter  **i**  with  **o**  in  **Artificial intelligence**

# %%
x = "Artifical Intelligence"
new_word = x.replace('i','o')
print(new_word)
# Out:
# Artofocal Intellogence

# %% [markdown]
# 12 - convert the text  **DATA Science**  into lower case ( as **data science**)

# %%
x = "DATA Science"
x.lower()
# Out:
# 'data science'

# %% [markdown]
# 13 - convert the text  **DATA Science**  into UPPER case ( as **DATA SCIENCE**)

# %%
x = "DATA Science"
x.upper()
# Out:
# 'DATA SCIENCE'

# %% [markdown]
# 14 - reverse the given String  **Artificial intelligence**

# %%
x = "Artifical Intelligence"
x[::-1]
# Out:
# 'ecnegilletnI lacifitrA'

# %% [markdown]
# ###Comparision Operators

# %% [markdown]
# 15 - Compare two number a =150, b = 225 and print if they are:
#
#         equal,
#         greater,
#         greater than or equal to,
#         less,
#         less than or equal to,
#         not equal
#
#         example : a < b
#                   print("a is less than b")

# %%
a = int(input("enter a number "))
b = int(input("enter a number "))

if a == b:
    print("a is equal to b")
elif a > b:
    print("a is greater than b")
elif a >= b:
    print("a is greater than or equal to b")
elif a <= b:
    print("a is less than or equal to b")
elif a < b:
    print("a < b")
elif a != b:
    print("a is not equal to b")
else:
    None
# Out:
# enter a number 25
# enter a number 25
# a is equal to b

# %% [markdown]
# ###Lists

# %% [markdown]
# 16 - Create a **list** of **lists** of integers elements

# %%
list_1 = [5,6,7]
list_2 = [2,3,4]
list_3 = [list_1,list_2]
list_3
# Out:
# [[5, 6, 7], [2, 3, 4]]

# %% [markdown]
# 17 - Create a **list** of **lists** of Text elements

# %%
list_1 = ['dog','cat','mouse']
list_2 = ['fish','dolphin','whale']
list_3 = [list_1,list_2]
list_3
# Out:
# [['dog', 'cat', 'mouse'], ['fish', 'dolphin', 'whale']]
